# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
voc_size = 10000

# %%
one_hot_rep = [one_hot(words , voc_size) for words in sent]
one_hot_rep
# Out:
# [[2995, 8889, 4188, 4929],
#  [2995, 8889, 4188, 6363],
#  [2995, 6328, 4188, 4993],
#  [7433, 7495, 5937, 4208, 7368],
#  [7433, 7495, 5937, 4208, 1473],
#  [1959, 2995, 7849, 4188, 684],
#  [8726, 9484, 1546, 4208]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import pad_sequences

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_rep , maxlen=sent_length , padding = 'pre')
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 2995, 8889, 4188, 4929],
#        [   0,    0,    0,    0, 2995, 8889, 4188, 6363],
#        [   0,    0,    0,    0, 2995, 6328, 4188, 4993],
#        [   0,    0,    0, 7433, 7495, 5937, 4208, 7368],
#        [   0,    0,    0, 7433, 7495, 5937, 4208, 1473],
#        [   0,    0,    0, 1959, 2995, 7849, 4188,  684],
#        [   0,    0,    0,    0, 8726, 9484, 1546, 4208]], dtype=int32)

# %%
feature_dimensions = 10

# %%
model = Sequential()
model.add(Embedding(voc_size , feature_dimensions))
model.compile('adam' , 'mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# array([[[-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [ 0.01085123,  0.039327  , -0.0243472 , -0.02743297,
#          -0.03381611, -0.02614169, -0.02658589,  0.02735705,
#           0.01750192, -0.00955839],
#         [ 0.02789736,  0.00697342, -0.03997675,  0.0001501 ,
#           0.03810802, -0.03035765, -0.00661218, -0.0364795 ,
#           0.04172638, -0.01148524],
#         [-0.04233563, -0.03566773, -0.02201588, -0.01216727,
#           0.02811095, -0.01598637, -0.03555173, -0.04189136,
#          -0.01462798, -0.01630766],
#         [-0.03456404, -0.00973171,  0.04455652, -0.02331976,
#          -0.0394603 , -0.03316694,  0.03907826,  0.0064538 ,
#          -0.00545038,  0.01389034]],
#
#        [[-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [ 0.01085123,  0.039327  , -0.0243472 , -0.02743297,
#          -0.03381611, -0.02614169, -0.02658589,  0.02735705,
#           0.01750192, -0.00955839],
#         [ 0.02789736,  0.00697342, -0.03997675,  0.0001501 ,
#           0.03810802, -0.03035765, -0.00661218, -0.0364795 ,
#           0.04172638, -0.01148524],
#         [-0.04233563, -0.03566773, -0.02201588, -0.01216727,
#           0.02811095, -0.01598637, -0.03555173, -0.04189136,
#          -0.01462798, -0.01630766],
#         [-0.02776342,  0.02558878, -0.02167211, -0.04352707,
#           0.03756669, -0.02020401, -0.03962482, -0.00320896,
#           0.0414454 ,  0.02637101]],
#
#        [[-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [ 0.01085123,  0.039327  , -0.0243472 , -0.02743297,
#          -0.03381611, -0.02614169, -0.02658589,  0.02735705,
#           0.01750192, -0.00955839],
#         [-0.04768495, -0.0290483 ,  0.00220013, -0.02982007,
#          -0.02270861,  0.02263622, -0.04575175, -0.03764304,
#          -0.03568663, -0.00489082],
#         [-0.04233563, -0.03566773, -0.02201588, -0.01216727,
#           0.02811095, -0.01598637, -0.03555173, -0.04189136,
#          -0.01462798, -0.01630766],
#         [-0.0484151 ,  0.04562321, -0.03771082, -0.03958373,
#           0.00801083,  0.02597263,  0.03667806,  0.04966665,
#           0.03751519, -0.00406374]],
#
#        [[-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [ 0.0118884 , -0.04787787,  0.00222385, -0.02710652,
#          -0.04491836,  0.00264927, -0.01613479,  0.00836512,
#          -0.03058239,  0.00392886],
#         [-0.01059991,  0.03019685, -0.03243864,  0.00899944,
#          -0.00635973,  0.00502859,  0.01053857,  0.0164677 ,
#           0.01574219,  0.03592441],
#         [-0.00060443, -0.04464933,  0.04107955, -0.02619615,
#           0.01955706,  0.03855633, -0.03765777, -0.00901916,
#           0.01450871,  0.04168825],
#         [-0.00121551,  0.02519716,  0.0339028 ,  0.02041506,
#           0.00644473, -0.02573183,  0.00524837, -0.02771492,
#           0.03351834,  0.04542467],
#         [-0.0415509 , -0.0086965 ,  0.00256356, -0.0250283 ,
#          -0.04252623,  0.02835706,  0.00331712, -0.04651631,
#           0.00786187, -0.01305326]],
#
#        [[-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [ 0.0118884 , -0.04787787,  0.00222385, -0.02710652,
#          -0.04491836,  0.00264927, -0.01613479,  0.00836512,
#          -0.03058239,  0.00392886],
#         [-0.01059991,  0.03019685, -0.03243864,  0.00899944,
#          -0.00635973,  0.00502859,  0.01053857,  0.0164677 ,
#           0.01574219,  0.03592441],
#         [-0.00060443, -0.04464933,  0.04107955, -0.02619615,
#           0.01955706,  0.03855633, -0.03765777, -0.00901916,
#           0.01450871,  0.04168825],
#         [-0.00121551,  0.02519716,  0.0339028 ,  0.02041506,
#           0.00644473, -0.02573183,  0.00524837, -0.02771492,
#           0.03351834,  0.04542467],
#         [ 0.00836807,  0.02907607,  0.01894292,  0.0029927 ,
#           0.0007848 , -0.04144472, -0.02338286,  0.04304056,
#          -0.00904906, -0.04974731]],
#
#        [[-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.00513718, -0.03107899, -0.02194899, -0.03459853,
#           0.03810921, -0.03512456,  0.04305774, -0.03694648,
#           0.00742323,  0.0053098 ],
#         [ 0.01085123,  0.039327  , -0.0243472 , -0.02743297,
#          -0.03381611, -0.02614169, -0.02658589,  0.02735705,
#           0.01750192, -0.00955839],
#         [ 0.0364679 ,  0.03392233,  0.03830289, -0.01057534,
#          -0.04609995,  0.03165436, -0.02500687, -0.04651053,
#          -0.02513525,  0.00239822],
#         [-0.04233563, -0.03566773, -0.02201588, -0.01216727,
#           0.02811095, -0.01598637, -0.03555173, -0.04189136,
#          -0.01462798, -0.01630766],
#         [-0.04084731, -0.04758542,  0.04322797, -0.01778274,
#          -0.00352416, -0.02976161,  0.02006112, -0.04646388,
#           0.04859732,  0.04015655]],
#
#        [[-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [-0.03362535,  0.03720688, -0.00884422, -0.04370229,
#          -0.00469816, -0.03520918,  0.01476059, -0.02204958,
#           0.03127227,  0.02143525],
#         [ 0.04439164,  0.0321802 ,  0.02678636, -0.01370022,
#          -0.01197358,  0.03426946, -0.00179971, -0.03395921,
#           0.03640253, -0.0361778 ],
#         [ 0.00217833,  0.0409932 ,  0.01842393, -0.00282811,
#          -0.02524444,  0.00622885,  0.01675303,  0.03137598,
#          -0.04664606, -0.03372729],
#         [ 0.01442409, -0.04754601,  0.02951146, -0.04327279,
#           0.04571551, -0.04367035, -0.02875819, -0.01194059,
#          -0.00414862, -0.04923601],
#         [-0.00121551,  0.02519716,  0.0339028 ,  0.02041506,
#           0.00644473, -0.02573183,  0.00524837, -0.02771492,
#           0.03351834,  0.04542467]]], dtype=float32)
